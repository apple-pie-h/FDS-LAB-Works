# %% [markdown]
# <a href="https://colab.research.google.com/github/apple-pie-h/FDS-LAB-Works/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 2: Hypothesis tests (eg: t-tests, Z-tests) on sample datasets to compare population means

# %% [markdown]
# ##One-Sample t-Test

# %%
import numpy as np
import scipy.stats as stats

# %%
#data
scores=[78,72,74,76,73,79,77,71,70.74]
population_mean=75
n=len(scores)

# %%
#sample statistics
sample_mean=np.mean(scores)
sample_std=np.std(scores,ddof=1)

# %%
#calculate t-statistic
t_stat=(sample_mean-population_mean)/(sample_std/np.sqrt(n))

# %%
#degree of freedom
df=n-1
#two tailed p-value
p_value=2*stats.t.sf(abs(t_stat),df)
#results
print(f"Sample Mean:{sample_mean:.2f}")
print(f"t-statistic: {t_stat:.2f}")
print(f"p-value: {p_value:.4f}")
# Out:
# Sample Mean:74.53
# t-statistic: -0.46
# p-value: 0.6575

# %%
if p_value < 0.05:
  print("Reject the null hypothesis: The sample mean is significantly different.")
else:
  print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# ##Two-Sample t-Test

# %%
#Data
class_a=[85,88.90,92,86,84,87,89.91,93]
class_b=[78,80,82,79,81,77,83,76,75,80]

# %%
#two sample t-test
t_stat, p_value = stats.ttest_ind(class_a, class_b, equal_var=False)

# %%
# Results
print(f"t-statistic:{t_stat:.2f}")
print(f"p-value: {p_value:.4f}")
if p_value < 0.05:
  print("Reject the null hypothesis: The means are significantly different.")
else:
  print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# t-statistic:6.43
# p-value: 0.0000
# Reject the null hypothesis: The means are significantly different.

# %% [markdown]
# #One-Sample z-Test

# %%
#Data
sample_mean=495
population_mean=500
population_std=10
n=40

# %%
#calculate z-statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# %%
# Calculate p-value (two-tailed)
p_value = 2 *stats.norm.sf(abs(z_stat))

# %%
# Results
print(f"z-statistic:{z_stat:.2f}")
print(f"p-value: {p_value:.4f}")
# Out:
# z-statistic:-3.16
# p-value: 0.0016

# %%
if p_value < 0.05:
  print("Reject the null hypothesis: The sample mean is significantly different.")
else:
  print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Reject the null hypothesis: The sample mean is significantly different.

# %% [markdown]
# ##Two-Sample z-Test

# %%
# Data
mean1, std1, n1 = 495, 10, 50
mean2, std2, n2 = 500, 12, 60

# %%
# Calculate z-statistic
z_stat = (mean1 - mean2) / ((std1**2 / n1 + std2**2 / n2) ** 0.5)

# %%
# Two-tailed p-value
p_value = 2 * stats.norm.sf(abs(z_stat))

# %%
# Results
print(f"z-statistic:{z_stat:.2f}")
print(f"p-value: {p_value:.4f}")
# Out:
# z-statistic:-2.38
# p-value: 0.0171

# %%
if p_value < 0.05:
  print("Reject the null hypothesis: The means are significantly different.")
else:
  print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Reject the null hypothesis: The means are significantly different.
